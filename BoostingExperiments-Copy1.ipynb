# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pytorch_memlab in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: calmsize in /usr/local/lib/python3.6/dist-packages (from pytorch_memlab->-r requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.6/dist-packages (from pytorch_memlab->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytorch_memlab->-r requirements.txt (line 1)) (41.0.1)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.6/dist-packages (from pytorch_memlab->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->pytorch_memlab->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->pytorch_memlab->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->pytorch_memlab->-r requirements.txt (line 1)) (0.7)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->pytorch_memlab->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->pytorch_memlab->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18->pytorch_memlab->-r requirements.txt (line 1)) (2019.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.18->pytorch_memlab->-r requirements.txt (line 1)) (1.12.0)
# WARNING: You are using pip version 19.2.1, however version 20.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from __future__ import print_function
import torch
from torchvision import datasets, transforms
import numpy as np
from WeakLearners import WongNeuralNetCIFAR10
import matplotlib.pyplot as plt

# %%
from Boosting import runMemlessCifarBoosting

# %%
import utils

# %%
cuda = torch.device('cuda:0')

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Vanilla PreactResNet

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Normalize the test set same as training set without augmentation
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = datasets.CIFAR10(
    root="./data", train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=100, shuffle=True, num_workers=2)

testset = datasets.CIFAR10(
    root="./data", train=False, download=True, transform=transform_test)
test_loader = torch.utils.data.DataLoader(
    testset, batch_size=300, shuffle=True, num_workers=2)

# %%
cifar10_vanilla = WongNeuralNetCIFAR10()
cifar10_vanilla.fit(train_loader, test_loader, alpha = 0, epochs = 1, adv=False, epsilon=0)

# %%
cifar10_vanilla.plot_val_accuracies()

# %%
print(len(cifar10_vanilla.iters), len(cifar10_vanilla.val_accuracies))

# %% [markdown]
# ## Experiments for CIFAR10 boosting

# %%
# maxIt_vals = [10, 20, 30, 50, 100]
# maxIt_vals = [10, 50, 100, 500]
maxIt_vals = [10, 50, 100]
# default maxIt for weak learner is infinity (i.e. runs each epoch on the entire batch)

# %%
num_wl = 100 # maybe around 100? #later: maybe change this to an array?
num_epochs = 1

# %%
all_val_accuracies = []
all_wl = []
all_wl_weights = []

# %%
from pytorch_memlab import LineProfiler
from Boosting import SchapireWongMulticlassBoostingMemoryLess
with LineProfiler(runMemlessCifarBoosting, SchapireWongMulticlassBoostingMemoryLess) as prof:
    for maxIt in maxIt_vals:
        wl, wl_weights, val_accuracies = runMemlessCifarBoosting(num_wl, maxIt, num_epochs)
        all_val_accuracies.append(val_accuracies)
        all_wl.append(wl)
        all_wl_weights.append(wl_weights)
prof.display()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------------------------------------------
# Training 0th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 143831040
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/cifar.py:118: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   img, target = self.data[index], self.targets[index]
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:893: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10816
# Alpha:  0.00906691511901982
# After newest WL score is:  0.065
# ----------------------------------------------------------------------------------------------------
# Training 1th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142307328
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1107
# Alpha:  0.012035587669145706
# After newest WL score is:  0.11
# ----------------------------------------------------------------------------------------------------
# Training 2th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13884
# Alpha:  0.04234633996828277
# After newest WL score is:  0.12
# ----------------------------------------------------------------------------------------------------
# Training 3th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10148
# Alpha:  0.0007253039449730303
# After newest WL score is:  0.12
# ----------------------------------------------------------------------------------------------------
# Training 4th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11576
# Alpha:  0.015774206623054707
# After newest WL score is:  0.12
# ----------------------------------------------------------------------------------------------------
# Training 5th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13474
# Alpha:  0.03233913037870704
# After newest WL score is:  0.13
# ----------------------------------------------------------------------------------------------------
# Training 6th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10254
# Alpha:  0.0022851228248971637
# After newest WL score is:  0.13
# ----------------------------------------------------------------------------------------------------
# Training 7th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11138
# Alpha:  0.011184657431791147
# After newest WL score is:  0.13
# ----------------------------------------------------------------------------------------------------
# Training 8th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10156
# Alpha:  -0.005201397043011088
# After newest WL score is:  0.13
# ----------------------------------------------------------------------------------------------------
# Training 9th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10678
# Alpha:  0.009856830410373893
# After newest WL score is:  0.13
# ----------------------------------------------------------------------------------------------------
# Training 10th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13038
# Alpha:  0.02994498660875105
# After newest WL score is:  0.155
# ----------------------------------------------------------------------------------------------------
# Training 11th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11132
# Alpha:  0.013474802675433346
# After newest WL score is:  0.155
# ----------------------------------------------------------------------------------------------------
# Training 12th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1206
# Alpha:  0.013574973542277756
# After newest WL score is:  0.15
# ----------------------------------------------------------------------------------------------------
# Training 13th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1033
# Alpha:  -0.003978246499529936
# After newest WL score is:  0.15
# ----------------------------------------------------------------------------------------------------
# Training 14th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12284
# Alpha:  0.023653452877614806
# After newest WL score is:  0.16
# ----------------------------------------------------------------------------------------------------
# Training 15th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10126
# Alpha:  -0.004543604666225121
# After newest WL score is:  0.16
# ----------------------------------------------------------------------------------------------------
# Training 16th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10026
# Alpha:  -0.0043170207755639746
# After newest WL score is:  0.14
# ----------------------------------------------------------------------------------------------------
# Training 17th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1144
# Alpha:  0.008309752338607044
# After newest WL score is:  0.145
# ----------------------------------------------------------------------------------------------------
# Training 18th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.16876
# Alpha:  0.06621702517803263
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 19th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1211
# Alpha:  0.01869165516139694
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 20th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10726
# Alpha:  0.0038904462146268247
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 21th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10772
# Alpha:  0.0023155644455929592
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 22th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.15382
# Alpha:  0.05514675280907373
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 23th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13858
# Alpha:  0.038178951805225264
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 24th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12826
# Alpha:  0.01915208699321525
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 25th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11912
# Alpha:  0.010984822971399903
# After newest WL score is:  0.16
# ----------------------------------------------------------------------------------------------------
# Training 26th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10136
# Alpha:  -0.011145433836573067
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 27th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10314
# Alpha:  -0.00633434340159063
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10014
# Alpha:  -0.01535242941062343
# After newest WL score is:  0.155
# ----------------------------------------------------------------------------------------------------
# Training 30th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1
# Alpha:  -0.008913580884301794
# After newest WL score is:  0.16
# ----------------------------------------------------------------------------------------------------
# Training 31th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10844
# Alpha:  0.008956835581547693
# After newest WL score is:  0.16
# ----------------------------------------------------------------------------------------------------
# Training 32th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1
# Alpha:  -0.01242159069690999
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 33th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11066
# Alpha:  -7.00661104675728e-05
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 34th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11528
# Alpha:  0.004789568072210443
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 35th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10414
# Alpha:  -0.00528193938359525
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 36th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.15014
# Alpha:  0.051671949718256366
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 37th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11928
# Alpha:  0.002892815822174771
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 38th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11896
# Alpha:  -0.0006461256187059704
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 39th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12556
# Alpha:  0.00905249457724421
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 40th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12932
# Alpha:  0.02708352628779775
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 41th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13562
# Alpha:  0.02722808231081662
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 42th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11614
# Alpha:  -0.0056421098703078746
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 43th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1117
# Alpha:  0.007944984851224657
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 44th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1426
# Alpha:  0.020835284534997476
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 45th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.15856
# Alpha:  0.03641802052229392
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 46th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13788
# Alpha:  0.03047665155921366
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 47th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10776
# Alpha:  -0.015006189437029216
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 48th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12722
# Alpha:  0.009330570294528155
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 49th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13222
# Alpha:  0.01860245456539689
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 50th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12334
# Alpha:  -0.004271984836274172
# After newest WL score is:  0.165
# ----------------------------------------------------------------------------------------------------
# Training 51th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.16814
# Alpha:  0.05321855652059052
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 52th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1
# Alpha:  -0.0021987283009872304
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 53th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11288
# Alpha:  0.006485275967996487
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 54th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10938
# Alpha:  0.0008171600152906109
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 55th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.14318
# Alpha:  0.03281910751884984
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 56th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.15566
# Alpha:  0.04675917521874914
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 57th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10088
# Alpha:  -0.011621483464533738
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 58th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.14482
# Alpha:  0.020365043867508162
# After newest WL score is:  0.2
# ----------------------------------------------------------------------------------------------------
# Training 59th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142389248
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10872
# Alpha:  -0.0036842993765051715
# After newest WL score is:  0.2
# ----------------------------------------------------------------------------------------------------
# Training 60th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13174
# Alpha:  0.024905534943551563
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 61th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.09994
# Alpha:  -0.010186653157063274
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 62th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1005
# Alpha:  0.017838772824717988
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 63th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12258
# Alpha:  0.009182339553941005
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 64th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12144
# Alpha:  0.023251405190395744
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 65th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10042
# Alpha:  -0.007614772565871832
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 66th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10522
# Alpha:  -0.002903348270387313
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 67th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10562
# Alpha:  -0.0013306252368079417
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 68th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13182
# Alpha:  0.002160872419548758
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 69th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11254
# Alpha:  -0.0051715562332462
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 70th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10482
# Alpha:  -0.0017307745386675114
# After newest WL score is:  0.19
# ----------------------------------------------------------------------------------------------------
# Training 71th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1059
# Alpha:  0.002699870241262828
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 72th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1124
# Alpha:  0.0027686306577439103
# After newest WL score is:  0.195
# ----------------------------------------------------------------------------------------------------
# Training 74th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.13658
# Alpha:  0.017705036062817498
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 75th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12196
# Alpha:  0.012420236618002395
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 76th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.14558
# Alpha:  0.04145226119153923
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 77th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1127
# Alpha:  0.003553805436439823
# After newest WL score is:  0.175
# ----------------------------------------------------------------------------------------------------
# Training 78th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11242
# Alpha:  -0.007224613378035254
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 79th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.16446
# Alpha:  0.05002831067400364
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 80th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1021
# Alpha:  -0.0026643100713246858
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 81th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.08964
# Alpha:  -0.014205781246656175
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 82th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10654
# Alpha:  -0.0024186441486464794
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 83th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.0999
# Alpha:  -0.001941327038859561
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 84th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10004
# Alpha:  -0.0013897427144010104
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 85th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10044
# Alpha:  -0.0008356999884925131
# After newest WL score is:  0.17
# ----------------------------------------------------------------------------------------------------
# Training 86th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11096
# Alpha:  -0.01342842108000619
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 87th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10534
# Alpha:  -0.0011525461884615011
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 88th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1124
# Alpha:  -0.003938178778735997
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 89th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.10838
# Alpha:  -0.005252923105531409
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 90th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.09978
# Alpha:  -0.001583704228420679
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 91th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12774
# Alpha:  0.013459862298478766
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 92th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11746
# Alpha:  -0.005015346058658911
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 93th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.12196
# Alpha:  -0.003193907688322129
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 94th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1202
# Alpha:  0.0034381425157842807
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 95th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11398
# Alpha:  0.0073709168129623475
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 96th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11322
# Alpha:  0.0009000390583061016
# After newest WL score is:  0.18
# ----------------------------------------------------------------------------------------------------
# Training 97th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.14178
# Alpha:  0.012412317920375813
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 98th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.1072
# Alpha:  -0.0009991346506129622
# After newest WL score is:  0.185
# ----------------------------------------------------------------------------------------------------
# Training 99th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 10
# Iteration:  1
# memory usage: 142127104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.11462
# Alpha:  0.005129173842397913
# After newest WL score is:  0.185
# Finished With:  0.215
# In  5170.074291  s
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------------------------------------------
# Training 0th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 142127104
# Iteration:  11
# memory usage: 142130688
# Iteration:  21
# memory usage: 142134272
# Iteration:  31
# memory usage: 142137856
# Iteration:  41
# memory usage: 142141440
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.3404
# Alpha:  0.2737503831765365
# After newest WL score is:  0.325
# ----------------------------------------------------------------------------------------------------
# Training 1th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 280790528
# Iteration:  11
# memory usage: 280794112
# Iteration:  21
# memory usage: 280797696
# Iteration:  31
# memory usage: 280801280
# Iteration:  41
# memory usage: 280804864
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.34338
# Alpha:  0.2535049660068669
# After newest WL score is:  0.325
# ----------------------------------------------------------------------------------------------------
# Training 2th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.32386
# Alpha:  0.19468361211988514
# After newest WL score is:  0.33
# ----------------------------------------------------------------------------------------------------
# Training 3th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 279741952
# Iteration:  11
# memory usage: 279745536
# Iteration:  21
# memory usage: 279749120
# Iteration:  31
# memory usage: 279752704
# Iteration:  41
# memory usage: 279756288
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.31016
# Alpha:  0.20352106724664615
# After newest WL score is:  0.35
# ----------------------------------------------------------------------------------------------------
# Training 4th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141602816
# Iteration:  11
# memory usage: 141606400
# Iteration:  21
# memory usage: 141609984
# Iteration:  31
# memory usage: 141613568
# Iteration:  41
# memory usage: 141617152
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.24522
# Alpha:  0.12237751603955556
# After newest WL score is:  0.34
# ----------------------------------------------------------------------------------------------------
# Training 5th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 278693376
# Iteration:  11
# memory usage: 278696960
# Iteration:  21
# memory usage: 278700544
# Iteration:  31
# memory usage: 278704128
# Iteration:  41
# memory usage: 278707712
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.27846
# Alpha:  0.16170169280134236
# After newest WL score is:  0.345
# ----------------------------------------------------------------------------------------------------
# Training 6th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.31994
# Alpha:  0.18819439649006986
# After newest WL score is:  0.335
# ----------------------------------------------------------------------------------------------------
# Training 7th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 278824448
# Iteration:  11
# memory usage: 278828032
# Iteration:  21
# memory usage: 278831616
# Iteration:  31
# memory usage: 278835200
# Iteration:  41
# memory usage: 278838784
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.28582
# Alpha:  0.11792046495311943
# After newest WL score is:  0.355
# ----------------------------------------------------------------------------------------------------
# Training 8th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.23198
# Alpha:  0.10791334111788509
# After newest WL score is:  0.37
# ----------------------------------------------------------------------------------------------------
# Training 9th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 279741952
# Iteration:  11
# memory usage: 279745536
# Iteration:  21
# memory usage: 279749120
# Iteration:  31
# memory usage: 279752704
# Iteration:  41
# memory usage: 279756288
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.32276
# Alpha:  0.14933002178609894
# After newest WL score is:  0.38
# ----------------------------------------------------------------------------------------------------
# Training 10th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141602816
# Iteration:  11
# memory usage: 141606400
# Iteration:  21
# memory usage: 141609984
# Iteration:  31
# memory usage: 141613568
# Iteration:  41
# memory usage: 141617152
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.35492
# Alpha:  0.16874967719322811
# After newest WL score is:  0.385
# ----------------------------------------------------------------------------------------------------
# Training 11th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 278431232
# Iteration:  11
# memory usage: 278434816
# Iteration:  21
# memory usage: 278438400
# Iteration:  31
# memory usage: 278441984
# Iteration:  41
# memory usage: 278445568
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.29968
# Alpha:  0.1253756728930265
# After newest WL score is:  0.38
# ----------------------------------------------------------------------------------------------------
# Training 12th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.27354
# Alpha:  0.11466446523123042
# After newest WL score is:  0.37
# ----------------------------------------------------------------------------------------------------
# Training 13th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 278824448
# Iteration:  11
# memory usage: 278828032
# Iteration:  21
# memory usage: 278831616
# Iteration:  31
# memory usage: 278835200
# Iteration:  41
# memory usage: 278838784
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.162
# Alpha:  0.0760267836520098
# After newest WL score is:  0.37
# ----------------------------------------------------------------------------------------------------
# Training 14th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.26418
# Alpha:  0.10339003263599392
# After newest WL score is:  0.385
# ----------------------------------------------------------------------------------------------------
# Training 15th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 141389824
# Iteration:  11
# memory usage: 141393408
# Iteration:  21
# memory usage: 141396992
# Iteration:  31
# memory usage: 141400576
# Iteration:  41
# memory usage: 141404160
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.26052
# Alpha:  0.095832604307487
# After newest WL score is:  0.385
# ----------------------------------------------------------------------------------------------------
# Training 16th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 278824448
# Iteration:  11
# memory usage: 278828032
# Iteration:  21
# memory usage: 142887936
# Iteration:  31
# memory usage: 142891520
# Iteration:  41
# memory usage: 142895104
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.25446
# Alpha:  0.10585255984639273
# After newest WL score is:  0.355
# ----------------------------------------------------------------------------------------------------
# Training 17th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 281576960
# Iteration:  11
# memory usage: 281580544
# Iteration:  21
# memory usage: 281584128
# Iteration:  31
# memory usage: 281587712
# Iteration:  41
# memory usage: 281591296
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.20602
# Alpha:  0.06554282487225932
# After newest WL score is:  0.355
# ----------------------------------------------------------------------------------------------------
# Training 18th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 417881088
# Iteration:  11
# memory usage: 417884672
# Iteration:  21
# memory usage: 417888256
# Iteration:  31
# memory usage: 417891840
# Iteration:  41
# memory usage: 417895424
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.28138
# Alpha:  0.09940847605245269
# After newest WL score is:  0.37
# ----------------------------------------------------------------------------------------------------
# Training 19th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 419453952
# Iteration:  11
# memory usage: 419457536
# Iteration:  21
# memory usage: 419461120
# Iteration:  31
# memory usage: 419464704
# Iteration:  41
# memory usage: 419468288
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.29568
# Alpha:  0.11215387245945703
# After newest WL score is:  0.335
# ----------------------------------------------------------------------------------------------------
# Training 20th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 419453952
# Iteration:  11
# memory usage: 419457536
# Iteration:  21
# memory usage: 419461120
# Iteration:  31
# memory usage: 419464704
# Iteration:  41
# memory usage: 419468288
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.21776
# Alpha:  0.05291782944396631
# After newest WL score is:  0.34
# ----------------------------------------------------------------------------------------------------
# Training 21th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 557593088
# Iteration:  11
# memory usage: 557596672
# Iteration:  21
# memory usage: 557600256
# Iteration:  31
# memory usage: 557603840
# Iteration:  41
# memory usage: 557607424
# After newest WL score is:  0.345
# ----------------------------------------------------------------------------------------------------
# Training 23th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 693635072
# Iteration:  11
# memory usage: 693638656
# Iteration:  21
# memory usage: 693642240
# Iteration:  31
# memory usage: 693645824
# Iteration:  41
# memory usage: 693649408
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.27884
# Alpha:  0.07880213639975094
# After newest WL score is:  0.36
# ----------------------------------------------------------------------------------------------------
# Training 24th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 691931136
# Iteration:  11
# memory usage: 691934720
# Iteration:  21
# memory usage: 691938304
# Iteration:  31
# memory usage: 691941888
# Iteration:  41
# memory usage: 691945472
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.24158
# Alpha:  0.07512619159860597
# After newest WL score is:  0.37
# ----------------------------------------------------------------------------------------------------
# Training 25th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 50
# Iteration:  1
# memory usage: 828857856
# Iteration:  11
# memory usage: 828861440
# Iteration:  21
# memory usage: 828865024
# ...
# Full Accuracy:  0.47214
# Alpha:  0.09527572339608822
# After newest WL score is:  0.615
# ----------------------------------------------------------------------------------------------------
# Training 8th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 1363621376
# Iteration:  11
# memory usage: 1363624960
# Iteration:  21
# memory usage: 1363628544
# Iteration:  31
# memory usage: 1363632128
# Iteration:  41
# memory usage: 1363635712
# Iteration:  51
# memory usage: 1363639296
# Iteration:  61
# memory usage: 1363642880
# Iteration:  71
# memory usage: 1363646464
# Iteration:  81
# memory usage: 1363650048
# Iteration:  91
# memory usage: 1363653632
# Iteration:  101
# memory usage: 1363657216
# Iteration:  111
# memory usage: 1363660800
# Iteration:  121
# memory usage: 1363664384
# Iteration:  131
# memory usage: 1363667968
# Iteration:  141
# memory usage: 1363671552
# Iteration:  151
# memory usage: 1363675136
# Iteration:  161
# memory usage: 1363678720
# Iteration:  171
# memory usage: 1363682304
# Iteration:  181
# memory usage: 1363685888
# Iteration:  191
# memory usage: 1363689472
# Iteration:  201
# memory usage: 1363693056
# Iteration:  211
# memory usage: 1363696640
# Iteration:  221
# memory usage: 1363700224
# Iteration:  231
# memory usage: 1363703808
# Iteration:  241
# memory usage: 1363707392
# Iteration:  251
# memory usage: 1363710976
# Iteration:  261
# memory usage: 1363714560
# Iteration:  271
# memory usage: 1363718144
# Iteration:  281
# memory usage: 1363721728
# Iteration:  291
# memory usage: 1363725312
# Iteration:  301
# memory usage: 1363728896
# Iteration:  311
# memory usage: 1363732480
# Iteration:  321
# memory usage: 1363736064
# Iteration:  331
# memory usage: 1363739648
# Iteration:  341
# memory usage: 1363743232
# Iteration:  351
# memory usage: 1363746816
# Iteration:  361
# memory usage: 1363750400
# Iteration:  371
# memory usage: 1363753984
# Iteration:  381
# memory usage: 1363757568
# Iteration:  391
# memory usage: 1363761152
# Iteration:  401
# memory usage: 1363764736
# Iteration:  411
# memory usage: 1363768320
# Iteration:  421
# memory usage: 1363771904
# Iteration:  431
# memory usage: 1363775488
# Iteration:  441
# memory usage: 1363779072
# Iteration:  451
# memory usage: 1363782656
# Iteration:  461
# memory usage: 1363786240
# Iteration:  471
# memory usage: 1363789824
# Iteration:  481
# memory usage: 1363793408
# Iteration:  491
# memory usage: 1363796992
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.45604
# Alpha:  0.10821825491515359
# After newest WL score is:  0.62
# ----------------------------------------------------------------------------------------------------
# Training 9th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 1498352640
# Iteration:  11
# memory usage: 1498356224
# Iteration:  21
# memory usage: 1498359808
# Iteration:  31
# memory usage: 1498363392
# Iteration:  41
# memory usage: 1498366976
# Iteration:  51
# memory usage: 1498370560
# Iteration:  61
# memory usage: 1498374144
# Iteration:  71
# memory usage: 1498377728
# Iteration:  81
# memory usage: 1498381312
# Iteration:  91
# memory usage: 1498384896
# Iteration:  101
# memory usage: 1498388480
# Iteration:  111
# memory usage: 1498392064
# Iteration:  121
# memory usage: 1498395648
# Iteration:  131
# memory usage: 1498399232
# Iteration:  141
# memory usage: 1498402816
# Iteration:  151
# memory usage: 1498406400
# Iteration:  161
# memory usage: 1498409984
# Iteration:  171
# memory usage: 1498413568
# Iteration:  181
# memory usage: 1498417152
# Iteration:  191
# memory usage: 1498420736
# Iteration:  201
# memory usage: 1498424320
# Iteration:  211
# memory usage: 1498427904
# Iteration:  221
# memory usage: 1498431488
# Iteration:  231
# memory usage: 1498435072
# Iteration:  241
# memory usage: 1498438656
# Iteration:  251
# memory usage: 1498442240
# Iteration:  261
# memory usage: 1498445824
# Iteration:  271
# memory usage: 1498449408
# Iteration:  281
# memory usage: 1498452992
# Iteration:  291
# memory usage: 1498456576
# Iteration:  301
# memory usage: 1498460160
# Iteration:  311
# memory usage: 1498463744
# Iteration:  321
# memory usage: 1498467328
# Iteration:  331
# memory usage: 1498470912
# Iteration:  341
# memory usage: 1498474496
# Iteration:  351
# memory usage: 1498478080
# Iteration:  361
# memory usage: 1498481664
# Iteration:  371
# memory usage: 1498485248
# Iteration:  381
# memory usage: 1498488832
# Iteration:  391
# memory usage: 1498492416
# Iteration:  401
# memory usage: 1498496000
# Iteration:  411
# memory usage: 1498499584
# Iteration:  421
# memory usage: 1498503168
# Iteration:  431
# memory usage: 1498506752
# Iteration:  441
# memory usage: 1498510336
# Iteration:  451
# memory usage: 1498513920
# Iteration:  461
# memory usage: 1498517504
# Iteration:  471
# memory usage: 1498521088
# Iteration:  481
# memory usage: 1498524672
# Iteration:  491
# memory usage: 1498528256
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.48654
# Alpha:  0.09056527988884713
# After newest WL score is:  0.625
# ----------------------------------------------------------------------------------------------------
# Training 10th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 1634132480
# Iteration:  11
# memory usage: 1634136064
# Iteration:  21
# memory usage: 1634139648
# Iteration:  31
# memory usage: 1634143232
# Iteration:  41
# memory usage: 1634146816
# Iteration:  51
# memory usage: 1634150400
# Iteration:  61
# memory usage: 1634153984
# Iteration:  71
# memory usage: 1634157568
# Iteration:  81
# memory usage: 1634161152
# Iteration:  91
# memory usage: 1634164736
# Iteration:  101
# memory usage: 1634168320
# Iteration:  111
# memory usage: 1634171904
# Iteration:  121
# memory usage: 1634175488
# Iteration:  131
# memory usage: 1634179072
# Iteration:  141
# memory usage: 1634182656
# Iteration:  151
# memory usage: 1634186240
# Iteration:  161
# memory usage: 1634189824
# Iteration:  171
# memory usage: 1634193408
# Iteration:  181
# memory usage: 1634196992
# Iteration:  191
# memory usage: 1634200576
# Iteration:  201
# memory usage: 1634204160
# Iteration:  211
# memory usage: 1634207744
# Iteration:  221
# memory usage: 1634211328
# Iteration:  231
# memory usage: 1634214912
# Iteration:  241
# memory usage: 1634218496
# Iteration:  251
# memory usage: 1634222080
# Iteration:  261
# memory usage: 1634225664
# Iteration:  271
# memory usage: 1634229248
# Iteration:  281
# memory usage: 1634232832
# Iteration:  291
# memory usage: 1634236416
# Iteration:  301
# memory usage: 1634240000
# Iteration:  311
# memory usage: 1634243584
# Iteration:  321
# memory usage: 1634247168
# Iteration:  331
# memory usage: 1634250752
# Iteration:  341
# memory usage: 1634254336
# Iteration:  351
# memory usage: 1634257920
# Iteration:  361
# memory usage: 1634261504
# Iteration:  371
# memory usage: 1634265088
# Iteration:  381
# memory usage: 1634268672
# Iteration:  391
# memory usage: 1634272256
# Iteration:  401
# memory usage: 1634275840
# Iteration:  411
# memory usage: 1634279424
# Iteration:  421
# memory usage: 1634283008
# Iteration:  431
# memory usage: 1634286592
# Iteration:  441
# memory usage: 1634290176
# Iteration:  451
# memory usage: 1634293760
# Iteration:  461
# memory usage: 1634297344
# Iteration:  471
# memory usage: 1634300928
# Iteration:  481
# memory usage: 1634304512
# Iteration:  491
# memory usage: 1634308096
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.45032
# Alpha:  0.06138237063028414
# After newest WL score is:  0.62
# ----------------------------------------------------------------------------------------------------
# Training 11th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 1771583488
# Iteration:  11
# memory usage: 1771587072
# Iteration:  21
# memory usage: 1771590656
# Iteration:  31
# memory usage: 1771594240
# Iteration:  41
# memory usage: 1771597824
# Iteration:  51
# memory usage: 1771601408
# Iteration:  61
# memory usage: 1771604992
# Iteration:  71
# memory usage: 1771608576
# Iteration:  81
# memory usage: 1771612160
# Iteration:  91
# memory usage: 1771615744
# Iteration:  101
# memory usage: 1771619328
# Iteration:  111
# memory usage: 1771622912
# Iteration:  121
# memory usage: 1771626496
# Iteration:  131
# memory usage: 1771630080
# Iteration:  141
# memory usage: 1771633664
# Iteration:  151
# memory usage: 1771637248
# Iteration:  161
# memory usage: 1771640832
# Iteration:  171
# memory usage: 1771644416
# Iteration:  181
# memory usage: 1771648000
# Iteration:  191
# memory usage: 1771651584
# Iteration:  201
# memory usage: 1771655168
# Iteration:  211
# memory usage: 1771658752
# Iteration:  221
# memory usage: 1771662336
# Iteration:  231
# memory usage: 1771665920
# Iteration:  241
# memory usage: 1771669504
# Iteration:  251
# memory usage: 1771673088
# Iteration:  261
# memory usage: 1771676672
# Iteration:  271
# memory usage: 1771680256
# Iteration:  281
# memory usage: 1771683840
# Iteration:  291
# memory usage: 1771687424
# Iteration:  301
# memory usage: 1771691008
# Iteration:  311
# memory usage: 1771694592
# Iteration:  321
# memory usage: 1771698176
# Iteration:  331
# memory usage: 143130112
# Iteration:  341
# memory usage: 143133696
# Iteration:  351
# memory usage: 143137280
# Iteration:  361
# memory usage: 143140864
# Iteration:  371
# memory usage: 143144448
# Iteration:  381
# memory usage: 143148032
# Iteration:  391
# memory usage: 143151616
# Iteration:  401
# memory usage: 143155200
# Iteration:  411
# memory usage: 143158784
# Iteration:  421
# memory usage: 143162368
# Iteration:  431
# memory usage: 143165952
# Iteration:  441
# memory usage: 143169536
# Iteration:  451
# memory usage: 143173120
# Iteration:  461
# memory usage: 143176704
# Iteration:  471
# memory usage: 143180288
# Iteration:  481
# memory usage: 143183872
# Iteration:  491
# memory usage: 143187456
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.4412
# Alpha:  0.04759328345514763
# After newest WL score is:  0.625
# ----------------------------------------------------------------------------------------------------
# Training 12th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 277743104
# Iteration:  11
# memory usage: 277746688
# Iteration:  21
# memory usage: 277750272
# Iteration:  31
# memory usage: 277753856
# Iteration:  41
# memory usage: 277757440
# Iteration:  51
# memory usage: 277761024
# Iteration:  61
# memory usage: 277764608
# Iteration:  71
# memory usage: 277768192
# Iteration:  81
# memory usage: 277771776
# Iteration:  91
# memory usage: 277775360
# Iteration:  101
# memory usage: 277778944
# Iteration:  111
# memory usage: 277782528
# Iteration:  121
# memory usage: 277786112
# Iteration:  131
# memory usage: 277789696
# Iteration:  141
# memory usage: 277793280
# Iteration:  151
# memory usage: 277796864
# Iteration:  161
# memory usage: 277800448
# Iteration:  171
# memory usage: 277804032
# Iteration:  181
# memory usage: 277807616
# Iteration:  191
# memory usage: 277811200
# Iteration:  201
# memory usage: 277814784
# Iteration:  211
# memory usage: 277818368
# Iteration:  221
# memory usage: 277821952
# Iteration:  231
# memory usage: 277825536
# Iteration:  241
# memory usage: 277829120
# Iteration:  251
# memory usage: 277832704
# Iteration:  261
# memory usage: 277836288
# Iteration:  271
# memory usage: 277839872
# Iteration:  281
# memory usage: 277843456
# Iteration:  291
# memory usage: 277847040
# Iteration:  301
# memory usage: 277850624
# Iteration:  311
# memory usage: 277854208
# Iteration:  321
# memory usage: 277857792
# Iteration:  331
# memory usage: 277861376
# Iteration:  341
# memory usage: 277864960
# Iteration:  351
# memory usage: 277868544
# Iteration:  361
# memory usage: 277872128
# Iteration:  371
# memory usage: 277875712
# Iteration:  381
# memory usage: 277879296
# Iteration:  391
# memory usage: 277882880
# Iteration:  401
# memory usage: 277886464
# Iteration:  411
# memory usage: 277890048
# Iteration:  421
# memory usage: 277893632
# Iteration:  431
# memory usage: 277897216
# Iteration:  441
# memory usage: 277900800
# Iteration:  451
# memory usage: 277904384
# Iteration:  461
# memory usage: 277907968
# Iteration:  471
# memory usage: 277911552
# Iteration:  481
# memory usage: 277915136
# Iteration:  491
# memory usage: 277918720
# targets: tensor([6, 9, 9,  ..., 9, 1, 1])
# Full Accuracy:  0.43124
# Alpha:  0.0802963665826181
# After newest WL score is:  0.625
# ----------------------------------------------------------------------------------------------------
# Training 13th weak learning
# Files already downloaded and verified
# adv: False
# maxIt: 500
# Iteration:  1
# memory usage: 415489024
# Iteration:  11
# memory usage: 415492608
# Iteration:  21
# memory usage: 415496192
# Iteration:  31
# memory usage: 415499776
# Iteration:  41
# memory usage: 415503360
# Iteration:  51
# memory usage: 415506944
# Iteration:  61
# memory usage: 415510528
# Iteration:  71
# memory usage: 415514112
# Iteration:  81
# memory usage: 415517696
# Iteration:  91
# memory usage: 415521280
# Iteration:  101
# memory usage: 415524864
# Iteration:  111
# memory usage: 415528448
# Iteration:  121
# memory usage: 415532032
# Iteration:  131
# memory usage: 415535616
# Iteration:  141
# memory usage: 415539200
# Iteration:  151
# memory usage: 415542784
# Iteration:  161
# memory usage: 415546368
# Iteration:  171
# memory usage: 415549952
# Iteration:  181
# memory usage: 415553536
# Iteration:  191
# memory usage: 415557120
# Iteration:  201
# memory usage: 415560704
# Iteration:  211
# memory usage: 415564288
# Iteration:  221
# memory usage: 415567872
# Iteration:  231
# memory usage: 415571456
# Iteration:  241
# memory usage: 415575040
# Iteration:  251
# memory usage: 415578624
# Iteration:  261
# memory usage: 415582208
# Iteration:  271
# memory usage: 415585792
# Iteration:  281
# memory usage: 415589376
# Iteration:  291
# memory usage: 415592960
# Iteration:  301
# memory usage: 415596544
# Iteration:  311
# memory usage: 415600128
# Iteration:  321
# memory usage: 415603712
# Iteration:  331
# memory usage: 415607296
# Iteration:  341
# memory usage: 415610880
# Iteration:  351
# memory usage: 415614464
# Iteration:  361
# memory usage: 415618048
# Iteration:  371
# memory usage: 415621632
# Iteration:  381
# memory usage: 415625216
# Iteration:  391
# memory usage: 415628800
# Iteration:  401
# memory usage: 415632384
# Iteration:  411
# memory usage: 415635968
# Iteration:  421
# memory usage: 415639552
# Iteration:  431
# memory usage: 415643136
# Iteration:  441
# memory usage: 415646720
# Iteration:  451
# memory usage: 415650304
# Iteration:  461
# memory usage: 415653888
# Iteration:  471
# memory usage: 415657472
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0fdeaecc21ec> in <module>
#       3 with LineProfiler(runMemlessCifarBoosting, SchapireWongMulticlassBoostingMemoryLess) as prof:
#       4     for maxIt in maxIt_vals:
# ----> 5         wl, wl_weights, val_accuracies = runMemlessCifarBoosting(num_wl, maxIt, num_epochs)
#       6         all_val_accuracies.append(val_accuracies)
#       7         all_wl.append(wl)
#
# /storage/AdversarialBoostingNeuralNets/Boosting.py in runMemlessCifarBoosting(numWL, maxIt, epochs)
#     459     # from pytorch_memlab import LineProfiler
#     460
# --> 461     wl, wlweights, val_accuracies = SchapireWongMulticlassBoostingMemoryLess(WongNeuralNetCIFAR10, numWL, datasets.CIFAR10, advDelta=0, alphaTol=1e-10, adv=False, maxIt=maxIt, predictionWeights=False, epochs=1)
#     462
#     463
#
# /storage/AdversarialBoostingNeuralNets/Boosting.py in SchapireWongMulticlassBoostingMemoryLess(weakLearner, numLearners, dataset, advDelta, alphaTol, adv, maxIt, predictionWeights, epochs)
#     308
#     309         h_i = weakLearner()
# --> 310         h_i.fit(train_loader, test_loader, C_t, adv=adv, maxIt=maxIt, predictionWeights=predictionWeights, epochs=epochs)
#     311
#     312         _, predictions, _ = pytorch_predict(h_i.model, train_loader_default, torch.device('cuda')) #y_true, y_pred, y_pred_prob
#
# /storage/AdversarialBoostingNeuralNets/WeakLearners.py in fit(self, train_loader, test_loader, C, batch_size, epochs, lr_schedule, lr_min, lr_max, weight_decay, early_stop, momentum, epsilon, alpha, delta_init, seed, opt_level, loss_scale, out_dir, maxIt, adv, predictionWeights)
#     272                 del X
#     273                 del y
# --> 274                 torch.cuda.empty_cache()
#     275
#     276             if early_stop:
#
# /usr/local/lib/python3.6/dist-packages/torch/cuda/memory.py in empty_cache()
#      85     """
#      86     if is_initialized():
# ---> 87         torch._C._cuda_emptyCache()
#      88
#      89
#
# KeyboardInterrupt:

# %%
# TODO: plot the accuracies for each usage of maxIt
legend_labels = []
for i in range(len(maxIt_vals)):
    maxIt = maxIt_vals[i]
    val_accuracies = all_val_accuracies[i]
    num_wl = len(all_wl[i])
    plt.plot(np.arange(maxIt, num_wl * maxIt + 1, maxIt), val_accuracies)
    legend_labels.append(f"MaxIt: {maxIt}")
plt.legend(legend_labels)
plt.show()

# %%
import csv

for i in range(len(maxIt_vals)):
    maxIt = maxIt_vals[i]
    wl = all_wl[i]
    wl_weights = all_wl_weights[i]
    val_accuracies = all_val_accuracies[i]
    wl_file = f"./results/wl_maxIt_{maxIt}.csv"
    wl_weights_file = f"./results/wl_weights_maxIt_{maxIt}.csv"
    val_acc_file = f"./results/val_accuracy_{maxIt}.csv"
    with open(wl_file, 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(wl)
    with open(wl_weights_file, 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(wl_weights)
    with open(val_acc_file, 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(val_accuracies)

# %%
# Potential idea: maybe compare wall-clock time b/w CIFAR10 boosting and regular nn training to reach a certain accuracy threshold?

# %% [markdown]
# ## Compare with other benchmarks? (i.e. other pretrained ensembles?)
